# %% [markdown]
# <a href="https://www.kaggle.com/code/idiaye/ollamarun?scriptVersionId=222180259" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# install ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
# install ollama python sdk
# !pip install ollama

# %%
# start ollama server as a background process
import subprocess
process = subprocess.Popen("ollama serve", shell=True)

# %%
# pull deepseek r1 model
# !ollama run deepseek-r1:1.5b

# %%
import ollama

# chat with model
result = ollama.chat(
    model='deepseek-r1:1.5b',
    messages=[{
        'role': 'user',
        'content': 'What are the steps involved in baking a chocolate cake?'
    }],
)

print(result.message.content)
