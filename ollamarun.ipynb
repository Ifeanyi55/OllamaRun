# %% [markdown]
# <a href="https://www.kaggle.com/code/idiaye/ollamarun?scriptVersionId=215431011" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# install ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
# start ollama server as a background process
import subprocess
process = subprocess.Popen("ollama serve", shell=True)

# %%
# install ollama python sdk
# !pip install ollama

# %%
# pull Microsoft phi3:mini model
# !ollama run phi3:mini

# %%
# chat with model
result = ollama.chat(
    model='phi3:mini',
    messages=[{
        'role': 'user',
        'content': 'what is the capital of France?'
    }],
)

print(result.message.content)
